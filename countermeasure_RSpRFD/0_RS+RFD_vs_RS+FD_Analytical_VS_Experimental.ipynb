# %%
import warnings; warnings.simplefilter('ignore')
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
params = {'axes.titlesize':'18',
          'xtick.labelsize':'18',
          'ytick.labelsize':'18',
          'font.size':'18',
          'legend.fontsize':'medium',
          'lines.linewidth':'2.5',
          'font.weight':'normal',
          'lines.markersize':'14'
          }
matplotlib.rcParams.update(params)
plt.rcParams["mathtext.fontset"] = "cm"
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
lst_eps = [round(np.log(val), 4) for val in range(2,8)]
fig_size = (6, 3)
font_x = 22
font_y = 18
lst_eps
# Out:
# [0.6931, 1.0986, 1.3863, 1.6094, 1.7918, 1.9459]

# %% [markdown]
# ## Experimental

# %% [markdown]
# Incorrect prior Dirichlet

# %%
dataset = 'acs' #'adults'
prior = 'Incorrect_DIR'

rs_fd_grr = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_grr.csv', header=None, index_col=0)
rs_rfd_grr = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_grr.csv', header=None, index_col=0)

rs_fd_sue_r = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_sue_r.csv', header=None, index_col=0)
rs_rfd_sue_r = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_sue_r.csv', header=None, index_col=0)

rs_fd_oue_r = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_oue_r.csv', header=None, index_col=0)
rs_rfd_oue_r = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_oue_r.csv', header=None, index_col=0)

print(rs_fd_grr.shape, rs_rfd_grr.shape, rs_fd_sue_r.shape, rs_rfd_sue_r.shape, rs_fd_oue_r.shape, rs_rfd_oue_r.shape)

plt.figure(figsize=fig_size)
plt.plot(rs_rfd_grr.mean(), label='RS+RFD[GRR]', markerfacecolor='none', marker='D')
plt.plot(rs_rfd_sue_r.mean(), label='RS+RFD[SUE-r]', marker='s',markerfacecolor='none')
plt.plot(rs_rfd_oue_r.mean(), label='RS+RFD[OUE-r]', marker='h',markerfacecolor='none')

plt.grid(color='grey', linestyle='dashdot', linewidth=0.5)
plt.plot(rs_fd_grr.mean(), label='RS+FD[GRR]', marker='*', markerfacecolor='none')
plt.plot(rs_fd_sue_r.mean(), label='RS+FD[SUE-r]', markerfacecolor='none', marker='o')
plt.plot(rs_fd_oue_r.mean(), label='RS+FD[OUE-r]', markerfacecolor='none', marker='v')
plt.ylabel('$MSE_{avg}$', fontsize=font_y)


plt.yscale('log')
plt.xlabel('$\epsilon$', fontsize=font_x)
plt.xticks(range(1,len(lst_eps)+1), ["ln("+str(val)+")" for val in range(2,8)])

plt.legend(ncol=2, columnspacing=0.1, loc='upper right', bbox_to_anchor=(1.05, 1.6));
plt.show()
# Out:
# (30, 6) (10, 6) (30, 6) (10, 6) (30, 6) (10, 6)

# %% [markdown]
# Incorrect prior Zipf

# %%
dataset = 'acs'
prior = 'Incorrect_ZIPF'

rs_fd_grr = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_grr.csv', header=None, index_col=0)
rs_rfd_grr = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_grr.csv', header=None, index_col=0)

rs_fd_sue_r = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_sue_r.csv', header=None, index_col=0)
rs_rfd_sue_r = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_sue_r.csv', header=None, index_col=0)

rs_fd_oue_r = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_oue_r.csv', header=None, index_col=0)
rs_rfd_oue_r = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_oue_r.csv', header=None, index_col=0)

print(rs_fd_grr.shape, rs_rfd_grr.shape, rs_fd_sue_r.shape, rs_rfd_sue_r.shape, rs_fd_oue_r.shape, rs_rfd_oue_r.shape)

plt.figure(figsize=fig_size)
plt.plot(rs_rfd_grr.mean(), label='RS+RFD[GRR]', markerfacecolor='none', marker='D')
plt.plot(rs_rfd_sue_r.mean(), label='RS+RFD[SUE-r]', marker='s',markerfacecolor='none')
plt.plot(rs_rfd_oue_r.mean(), label='RS+RFD[OUE-r]', marker='h',markerfacecolor='none')

plt.grid(color='grey', linestyle='dashdot', linewidth=0.5)
plt.plot(rs_fd_grr.mean(), label='RS+FD[GRR]', marker='*', markerfacecolor='none')
plt.plot(rs_fd_sue_r.mean(), label='RS+FD[SUE-r]', markerfacecolor='none', marker='o')
plt.plot(rs_fd_oue_r.mean(), label='RS+FD[OUE-r]', markerfacecolor='none', marker='v')
plt.ylabel('$MSE_{avg}$', fontsize=font_y)


plt.yscale('log')
plt.xlabel('$\epsilon$', fontsize=font_x)
plt.xticks(range(1,len(lst_eps)+1), ["ln("+str(val)+")" for val in range(2,8)])

plt.legend(ncol=2, columnspacing=0.1, loc='upper right', bbox_to_anchor=(1.05, 1.6));
plt.show()
# Out:
# (30, 6) (10, 6) (30, 6) (10, 6) (30, 6) (10, 6)

# %% [markdown]
# Incorrect prior Exponential

# %%
dataset = 'acs' 
prior = 'Incorrect_EXP'

rs_fd_grr = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_grr.csv', header=None, index_col=0)
rs_rfd_grr = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_grr.csv', header=None, index_col=0)

rs_fd_sue_r = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_sue_r.csv', header=None, index_col=0)
rs_rfd_sue_r = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_sue_r.csv', header=None, index_col=0)

rs_fd_oue_r = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_oue_r.csv', header=None, index_col=0)
rs_rfd_oue_r = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_oue_r.csv', header=None, index_col=0)

print(rs_fd_grr.shape, rs_rfd_grr.shape, rs_fd_sue_r.shape, rs_rfd_sue_r.shape, rs_fd_oue_r.shape, rs_rfd_oue_r.shape)

plt.figure(figsize=fig_size)
plt.plot(rs_rfd_grr.mean(), label='RS+RFD[GRR]', markerfacecolor='none', marker='D')
plt.plot(rs_rfd_sue_r.mean(), label='RS+RFD[SUE-r]', marker='s',markerfacecolor='none')
plt.plot(rs_rfd_oue_r.mean(), label='RS+RFD[OUE-r]', marker='h',markerfacecolor='none')

plt.grid(color='grey', linestyle='dashdot', linewidth=0.5)
plt.plot(rs_fd_grr.mean(), label='RS+FD[GRR]', marker='*', markerfacecolor='none')
plt.plot(rs_fd_sue_r.mean(), label='RS+FD[SUE-r]', markerfacecolor='none', marker='o')
plt.plot(rs_fd_oue_r.mean(), label='RS+FD[OUE-r]', markerfacecolor='none', marker='v')
plt.ylabel('$MSE_{avg}$', fontsize=font_y)


plt.yscale('log')
plt.xlabel('$\epsilon$', fontsize=font_x)
plt.xticks(range(1,len(lst_eps)+1), ["ln("+str(val)+")" for val in range(2,8)])

plt.legend(ncol=2, columnspacing=0.1, loc='upper right', bbox_to_anchor=(1.05, 1.6));
plt.show()
# Out:
# (30, 6) (10, 6) (30, 6) (10, 6) (30, 6) (10, 6)

# %% [markdown]
# Correct priors

# %%
dataset = 'acs'
prior = 'Correct'

rs_fd_grr = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_grr.csv', header=None, index_col=0)
rs_rfd_grr = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_grr.csv', header=None, index_col=0)

rs_fd_sue_r = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_sue_r.csv', header=None, index_col=0)
rs_rfd_sue_r = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_sue_r.csv', header=None, index_col=0)

rs_fd_oue_r = pd.read_csv('results/'+dataset+'/freq_est_results_rs_fd_oue_r.csv', header=None, index_col=0)
rs_rfd_oue_r = pd.read_csv('results/'+dataset+'/freq_est_results_'+prior+'_rs_rfd_oue_r.csv', header=None, index_col=0)

print(rs_fd_grr.shape, rs_rfd_grr.shape, rs_fd_sue_r.shape, rs_rfd_sue_r.shape, rs_fd_oue_r.shape, rs_rfd_oue_r.shape)

plt.figure(figsize=fig_size)
plt.plot(rs_rfd_grr.mean(), label='RS+RFD[GRR]', markerfacecolor='none', marker='D')
plt.plot(rs_rfd_sue_r.mean(), label='RS+RFD[SUE-r]', marker='s',markerfacecolor='none')
plt.plot(rs_rfd_oue_r.mean(), label='RS+RFD[OUE-r]', marker='h',markerfacecolor='none')

plt.grid(color='grey', linestyle='dashdot', linewidth=0.5)
plt.plot(rs_fd_grr.mean(), label='RS+FD[GRR]', marker='*', markerfacecolor='none')
plt.plot(rs_fd_sue_r.mean(), label='RS+FD[SUE-r]', markerfacecolor='none', marker='o')
plt.plot(rs_fd_oue_r.mean(), label='RS+FD[OUE-r]', markerfacecolor='none', marker='v')
plt.ylabel('$MSE_{avg}$', fontsize=font_y)

plt.yscale('log')
plt.xlabel('$\epsilon$', fontsize=font_x)
plt.xticks(range(1,len(lst_eps)+1), ["ln("+str(val)+")" for val in range(2,8)])

plt.legend(ncol=2, columnspacing=0.1, loc='upper right', bbox_to_anchor=(1.05, 1.6));
plt.show()
# Out:
# (30, 6) (10, 6) (30, 6) (10, 6) (30, 6) (10, 6)

# %% [markdown]
# ## Analytical RS+FD

# %% [markdown]
# Parameters

# %%
# Range of epsilon used in the experiments
lst_eps = [round(np.log(val),4) for val in range(2,8)] 

# Parameters of Adult Dataset. 
df = pd.read_csv('db_ACSEmployement.csv')
n = df.shape[0] #number of users
d = df.shape[1] #number of attributes
beta = 1/d #sampling rate
K = [df[att].unique().shape[0] for att in df.columns] #number of values per attribute

# %%
# from https://github.com/hharcolezi/ldp-protocols-mobility-cdrs/tree/main/papers/%5B2%5D
def Var_RSpFD_GRR(n, d, k, p, q): 
    f_vi = 0 # approximate variance
    
    sig_grr = (1/d) * (q + f_vi*(p-q) + (d-1)/k)
    
    var_grr = ((d**2 * sig_grr * (1-sig_grr))/(n*(p-q)**2))
    
    return var_grr

def Var_RSpFD_UE_r(n, d, k, p, q): 
    f_vi = 0 # approximate variance
    
    sig_ue_r = (1/d) * (f_vi * (p-q) + q + (d-1) * ((p/k) + ((k-1)/(k))*q) )
    
    var_ue_r = ((d**2 * sig_ue_r * (1-sig_ue_r))/(n*(p-q)**2))
    
    return var_ue_r

# %%
# Initialize list of averaged variance values per epsilon
lst_var_RSpFD_GRR = []
lst_var_RSpFD_SUE_r = []
lst_var_RSpFD_OUE_r = []

for eps in lst_eps:
    eps_l = np.log((np.exp(eps) - 1 + beta)/beta) #amplified epsilon
    
    # Initialize list of variance values per attribute
    lst_var_att_grr = []
    lst_var_att_sue_r = []
    lst_var_att_oue_r = []

    for k in K: # for each attribute
        
        p = np.exp(eps_l) / (np.exp(eps_l) + k - 1) # GRR
        q = (1 - p) / (k - 1) # GRR
        
        p_sue = np.exp(eps_l/2) / (np.exp(eps_l/2) + 1) #SUE
        q_sue = 1 - p_sue  #SUE
        
        p_oue = 1/2 #OUE
        q_oue = 1 / (np.exp(eps_l)+1) #OUE
        
        lst_var_att_grr.append(Var_RSpFD_GRR(n, d, k, p, q))
           
        lst_var_att_sue_r.append(Var_RSpFD_UE_r(n, d, k, p_sue, q_sue))
        
        lst_var_att_oue_r.append(Var_RSpFD_UE_r(n, d, k, p_oue, q_oue))           
           
    # We'll average the MSE over the number of attributes
    lst_var_RSpFD_GRR.append(np.mean(lst_var_att_grr))
    lst_var_RSpFD_SUE_r.append(np.mean(lst_var_att_sue_r))
    lst_var_RSpFD_OUE_r.append(np.mean(lst_var_att_oue_r))

# %% [markdown]
# ## Analytical RS+RFD

# %%
def Var_RSpRFD_GRR(n, d, k, p, q, f_prior): 
    f_vi = 0 # approximate variance
    
    sig_grr = (1/d) * (q + f_vi*(p-q) + (d-1)*f_prior)
    
    var_grr = ((d**2 * sig_grr * (1-sig_grr))/(n*(p-q)**2))
    
    return np.mean(var_grr)


def Var_RSpRFD_UE_r(n, d, k, p, q, f_prior): 
    f_vi = 0 # approximate variance
    
    sig_ue_r = (1/d) * (f_vi * (p-q) + q + (d-1)*(f_prior*(p-q)+q))
    
    var_ue_r = ((d**2 * sig_ue_r * (1-sig_ue_r))/(n*(p-q)**2))
    
    return np.mean(var_ue_r)

# %% [markdown]
# Incorrect priors DIR

# %%
nb_seed = 100

prior = 'Incorrect_DIR'

seed_RSpRFD_GRR = []
seed_RSpRFD_SUE_r  = []
seed_RSpRFD_OUE_r = []

for seed in range(nb_seed):

    freq_prior = []
    for k in K:

        freq = np.random.dirichlet(np.ones(k), size=1)[0]
        freq = freq/sum(freq)
        freq_prior.append(freq)
    
    # Initialize list of averaged variance values per epsilon
    lst_var_RSpRFD_GRR = []
    lst_var_RSpRFD_SUE_r = []
    lst_var_RSpRFD_OUE_r = []
    
    for eps in lst_eps:
        eps_l = np.log((np.exp(eps) - 1 + beta)/beta) #amplified epsilon
        # Initialize list of variance values per attribute
        lst_var_att_grr = []
        lst_var_att_sue_r = []
        lst_var_att_oue_r = []

        idx_k = 0
        for k in K: # for each attribute

            p = np.exp(eps_l) / (np.exp(eps_l) + k - 1) # GRR
            q = (1 - p) / (k - 1) # GRR

            p_sue = np.exp(eps_l/2) / (np.exp(eps_l/2) + 1) #SUE
            q_sue = 1 - p_sue  #SUE

            p_oue = 1/2 #OUE
            q_oue = 1 / (np.exp(eps_l)+1) #OUE

            lst_var_att_grr.append(Var_RSpRFD_GRR(n, d, k, p, q, freq_prior[idx_k]))

            lst_var_att_sue_r.append(Var_RSpRFD_UE_r(n, d, k, p_sue, q_sue, freq_prior[idx_k]))

            lst_var_att_oue_r.append(Var_RSpRFD_UE_r(n, d, k, p_oue, q_oue, freq_prior[idx_k]))           
            idx_k+=1

        # We'll average the MSE over the number of attributes
        lst_var_RSpRFD_GRR.append(np.mean(lst_var_att_grr))
        lst_var_RSpRFD_SUE_r.append(np.mean(lst_var_att_sue_r))
        lst_var_RSpRFD_OUE_r.append(np.mean(lst_var_att_oue_r))
        
    seed_RSpRFD_GRR.append(lst_var_RSpRFD_GRR)
    seed_RSpRFD_SUE_r.append(lst_var_RSpRFD_SUE_r)
    seed_RSpRFD_OUE_r.append(lst_var_RSpRFD_OUE_r)

# %%
plt.figure(figsize=fig_size)
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_GRR, axis=0), label='RS+RFD[GRR]', markerfacecolor='none', marker='D')
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_SUE_r, axis=0), label='RS+RFD[SUE-r]', marker='s',markerfacecolor='none')
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_OUE_r, axis=0), label='RS+RFD[OUE-r]', marker='h',markerfacecolor='none')

plt.grid(color='grey', linestyle='dashdot', linewidth=0.5)
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_GRR, label='RS+FD[GRR]', marker='*', markerfacecolor='none')
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_SUE_r, label='RS+FD[SUE-r]', markerfacecolor='none', marker='o')
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_OUE_r, label='RS+FD[OUE-r]', markerfacecolor='none', marker='v')
plt.ylabel('$MSE_{avg}$', fontsize=font_y)


plt.yscale('log')
plt.xlabel('$\epsilon$', fontsize=font_x)
plt.xticks(range(1,len(lst_eps)+1), ["ln("+str(val)+")" for val in range(2,8)])

plt.legend(ncol=2, columnspacing=0.1, loc='upper right', bbox_to_anchor=(1.05, 1.6));
plt.show()

# %% [markdown]
# Incorrect priors ZIPF

# %%
nb_seed = 100

prior = 'Incorrect_ZIPF'

seed_RSpRFD_GRR = []
seed_RSpRFD_SUE_r  = []
seed_RSpRFD_OUE_r = []

for seed in range(nb_seed):

    freq_prior = []
    for k in K:

        freq = np.histogram(np.random.zipf(a=1.01, size=100000), bins=k)[0]
        freq = freq/sum(freq)
        freq_prior.append(freq)
    
    # Initialize list of averaged variance values per epsilon
    lst_var_RSpRFD_GRR = []
    lst_var_RSpRFD_SUE_r = []
    lst_var_RSpRFD_OUE_r = []
    
    for eps in lst_eps:
        eps_l = np.log((np.exp(eps) - 1 + beta)/beta) #amplified epsilon
        # Initialize list of variance values per attribute
        lst_var_att_grr = []
        lst_var_att_sue_r = []
        lst_var_att_oue_r = []

        idx_k = 0
        for k in K: # for each attribute

            p = np.exp(eps_l) / (np.exp(eps_l) + k - 1) # GRR
            q = (1 - p) / (k - 1) # GRR

            p_sue = np.exp(eps_l/2) / (np.exp(eps_l/2) + 1) #SUE
            q_sue = 1 - p_sue  #SUE

            p_oue = 1/2 #OUE
            q_oue = 1 / (np.exp(eps_l)+1) #OUE

            lst_var_att_grr.append(Var_RSpRFD_GRR(n, d, k, p, q, freq_prior[idx_k]))

            lst_var_att_sue_r.append(Var_RSpRFD_UE_r(n, d, k, p_sue, q_sue, freq_prior[idx_k]))

            lst_var_att_oue_r.append(Var_RSpRFD_UE_r(n, d, k, p_oue, q_oue, freq_prior[idx_k]))           
            idx_k+=1

        # We'll average the MSE over the number of attributes
        lst_var_RSpRFD_GRR.append(np.mean(lst_var_att_grr))
        lst_var_RSpRFD_SUE_r.append(np.mean(lst_var_att_sue_r))
        lst_var_RSpRFD_OUE_r.append(np.mean(lst_var_att_oue_r))
        
    seed_RSpRFD_GRR.append(lst_var_RSpRFD_GRR)
    seed_RSpRFD_SUE_r.append(lst_var_RSpRFD_SUE_r)
    seed_RSpRFD_OUE_r.append(lst_var_RSpRFD_OUE_r)

# %%
plt.figure(figsize=fig_size)
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_GRR, axis=0), label='RS+RFD[GRR]', markerfacecolor='none', marker='D')
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_SUE_r, axis=0), label='RS+RFD[SUE-r]', marker='s',markerfacecolor='none')
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_OUE_r, axis=0), label='RS+RFD[OUE-r]', marker='h',markerfacecolor='none')

plt.grid(color='grey', linestyle='dashdot', linewidth=0.5)
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_GRR, label='RS+FD[GRR]', marker='*', markerfacecolor='none')
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_SUE_r, label='RS+FD[SUE-r]', markerfacecolor='none', marker='o')
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_OUE_r, label='RS+FD[OUE-r]', markerfacecolor='none', marker='v')
plt.ylabel('$MSE_{avg}$', fontsize=font_y)


plt.yscale('log')
plt.xlabel('$\epsilon$', fontsize=font_x)
plt.xticks(range(1,len(lst_eps)+1), ["ln("+str(val)+")" for val in range(2,8)])

plt.legend(ncol=2, columnspacing=0.1, loc='upper right', bbox_to_anchor=(1.05, 1.6));
plt.show()

# %% [markdown]
# Incorrect priors EXP

# %%
nb_seed = 100

prior = 'Incorrect_EXP'

seed_RSpRFD_GRR = []
seed_RSpRFD_SUE_r  = []
seed_RSpRFD_OUE_r = []

for seed in range(nb_seed):

    freq_prior = []
    for k in K:

        freq = np.histogram(np.random.exponential(size=100000), bins=k)[0]
        freq = freq/sum(freq)
        freq_prior.append(freq)
    
    # Initialize list of averaged variance values per epsilon
    lst_var_RSpRFD_GRR = []
    lst_var_RSpRFD_SUE_r = []
    lst_var_RSpRFD_OUE_r = []
    
    for eps in lst_eps:
        eps_l = np.log((np.exp(eps) - 1 + beta)/beta) #amplified epsilon
        # Initialize list of variance values per attribute
        lst_var_att_grr = []
        lst_var_att_sue_r = []
        lst_var_att_oue_r = []

        idx_k = 0
        for k in K: # for each attribute

            p = np.exp(eps_l) / (np.exp(eps_l) + k - 1) # GRR
            q = (1 - p) / (k - 1) # GRR

            p_sue = np.exp(eps_l/2) / (np.exp(eps_l/2) + 1) #SUE
            q_sue = 1 - p_sue  #SUE

            p_oue = 1/2 #OUE
            q_oue = 1 / (np.exp(eps_l)+1) #OUE

            lst_var_att_grr.append(Var_RSpRFD_GRR(n, d, k, p, q, freq_prior[idx_k]))

            lst_var_att_sue_r.append(Var_RSpRFD_UE_r(n, d, k, p_sue, q_sue, freq_prior[idx_k]))

            lst_var_att_oue_r.append(Var_RSpRFD_UE_r(n, d, k, p_oue, q_oue, freq_prior[idx_k]))           
            idx_k+=1

        # We'll average the MSE over the number of attributes
        lst_var_RSpRFD_GRR.append(np.mean(lst_var_att_grr))
        lst_var_RSpRFD_SUE_r.append(np.mean(lst_var_att_sue_r))
        lst_var_RSpRFD_OUE_r.append(np.mean(lst_var_att_oue_r))
        
    seed_RSpRFD_GRR.append(lst_var_RSpRFD_GRR)
    seed_RSpRFD_SUE_r.append(lst_var_RSpRFD_SUE_r)
    seed_RSpRFD_OUE_r.append(lst_var_RSpRFD_OUE_r)

# %%
plt.figure(figsize=fig_size)
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_GRR, axis=0), label='RS+RFD[GRR]', markerfacecolor='none', marker='D')
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_SUE_r, axis=0), label='RS+RFD[SUE-r]', marker='s',markerfacecolor='none')
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_OUE_r, axis=0), label='RS+RFD[OUE-r]', marker='h',markerfacecolor='none')

plt.grid(color='grey', linestyle='dashdot', linewidth=0.5)
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_GRR, label='RS+FD[GRR]', marker='*', markerfacecolor='none')
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_SUE_r, label='RS+FD[SUE-r]', markerfacecolor='none', marker='o')
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_OUE_r, label='RS+FD[OUE-r]', markerfacecolor='none', marker='v')
plt.ylabel('$MSE_{avg}$', fontsize=font_y)


plt.yscale('log')
plt.xlabel('$\epsilon$', fontsize=font_x)
plt.xticks(range(1,len(lst_eps)+1), ["ln("+str(val)+")" for val in range(2,8)])

plt.legend(ncol=2, columnspacing=0.1, loc='upper right', bbox_to_anchor=(1.05, 1.6));
plt.show()

# %% [markdown]
# Correct priors

# %%
from diffprivlib.mechanisms import Laplace

# For each attribute, count the number of people per value

dic_true = {att:{val:0 for val in np.unique(df[att])} for att in df.columns}

for att in df.columns:

    dfcp = df.groupby(att).count()
    n = df.shape[0]

    index = 0
    for val in dfcp.index:
        val_true = dfcp.values[index,0]
        dic_true[att][val] += val_true 
        index+=1

nb_seed = 100
seed_RSpRFD_GRR = []
seed_RSpRFD_SUE_r  = []
seed_RSpRFD_OUE_r = []

for seed in range(nb_seed):
    LAP_MECH = Laplace(epsilon=0.1/d, sensitivity=1)

    freq_prior = []
    for att in df.columns:

        freq = np.array([int(np.rint(LAP_MECH.randomise(val)).clip(0)) for val in dic_true[att].values()])
        freq = freq/sum(freq) 
        freq_prior.append(freq)
        
    # Initialize list of averaged variance values per epsilon
    lst_var_RSpRFD_GRR = []
    lst_var_RSpRFD_SUE_r = []
    lst_var_RSpRFD_OUE_r = []
    
    for eps in lst_eps:
        
        eps_l = np.log((np.exp(eps) - 1 + beta)/beta) #amplified epsilon
        
        # Initialize list of variance values per attribute
        lst_var_att_grr = []
        lst_var_att_sue_r = []
        lst_var_att_oue_r = []

        idx_k = 0
        for k in K: # for each attribute

            p = np.exp(eps_l) / (np.exp(eps_l) + k - 1) # GRR
            q = (1 - p) / (k - 1) # GRR

            p_sue = np.exp(eps_l/2) / (np.exp(eps_l/2) + 1) #SUE
            q_sue = 1 - p_sue  #SUE

            p_oue = 1/2 #OUE
            q_oue = 1 / (np.exp(eps_l)+1) #OUE

            lst_var_att_grr.append(Var_RSpRFD_GRR(n, d, k, p, q, freq_prior[idx_k]))

            lst_var_att_sue_r.append(Var_RSpRFD_UE_r(n, d, k, p_sue, q_sue, freq_prior[idx_k]))

            lst_var_att_oue_r.append(Var_RSpRFD_UE_r(n, d, k, p_oue, q_oue, freq_prior[idx_k]))           
            idx_k+=1

        # We'll average the MSE over the number of attributes
        lst_var_RSpRFD_GRR.append(np.mean(lst_var_att_grr))
        lst_var_RSpRFD_SUE_r.append(np.mean(lst_var_att_sue_r))
        lst_var_RSpRFD_OUE_r.append(np.mean(lst_var_att_oue_r))
        
    seed_RSpRFD_GRR.append(lst_var_RSpRFD_GRR)
    seed_RSpRFD_SUE_r.append(lst_var_RSpRFD_SUE_r)
    seed_RSpRFD_OUE_r.append(lst_var_RSpRFD_OUE_r)

# %%
plt.figure(figsize=fig_size)
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_GRR, axis=0), label='RS+RFD[GRR]', markerfacecolor='none', marker='D')
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_SUE_r, axis=0), label='RS+RFD[SUE-r]', marker='s',markerfacecolor='none')
plt.plot(range(1,len(lst_eps)+1), np.mean(seed_RSpRFD_OUE_r, axis=0), label='RS+RFD[OUE-r]', marker='h',markerfacecolor='none')

plt.grid(color='grey', linestyle='dashdot', linewidth=0.5)
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_GRR, label='RS+FD[GRR]', marker='*', markerfacecolor='none')
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_SUE_r, label='RS+FD[SUE-r]', markerfacecolor='none', marker='o')
plt.plot(range(1,len(lst_eps)+1), lst_var_RSpFD_OUE_r, label='RS+FD[OUE-r]', markerfacecolor='none', marker='v')
plt.ylabel('$MSE_{avg}$', fontsize=font_y)


plt.yscale('log')
plt.xlabel('$\epsilon$', fontsize=font_x)
plt.xticks(range(1,len(lst_eps)+1), ["ln("+str(val)+")" for val in range(2,8)])

plt.legend(ncol=2, columnspacing=0.1, loc='upper right', bbox_to_anchor=(1.05, 1.6));
plt.show()
